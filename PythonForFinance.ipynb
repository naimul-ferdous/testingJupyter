# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd

# %%
tickers = ['AAPL', 'MSFT', '^GSPC']

start_date = '2010-01-01'
end_date = '2016-12-31'

panel_data = data.DataReader(tickers, 'yahoo', start_date, end_date)

# %%
panel_data.head(9)
# Out:
# Attributes  Adj Close                              Close             \
# Symbols          AAPL       MSFT        ^GSPC       AAPL       MSFT
# Date
# 2009-12-31  26.061205  23.858992  1115.099976  30.104286  30.480000
# 2010-01-04  26.466835  24.226894  1132.989990  30.572857  30.950001
# 2010-01-05  26.512596  24.234720  1136.520020  30.625713  30.959999
# 2010-01-06  26.090879  24.085989  1137.140015  30.138571  30.770000
# 2010-01-07  26.042646  23.835503  1141.689941  30.082857  30.450001
# 2010-01-08  26.215786  23.999893  1144.979980  30.282858  30.660000
# 2010-01-11  25.984528  23.694611  1146.979980  30.015715  30.270000
# 2010-01-12  25.688946  23.538054  1136.219971  29.674286  30.070000
# 2010-01-13  26.051304  23.757231  1145.680054  30.092857  30.350000
#
# Attributes                    High                                Low  \
# Symbols           ^GSPC       AAPL       MSFT        ^GSPC       AAPL
# Date
# 2009-12-31  1115.099976  30.478571  30.990000  1127.640015  30.080000
# 2010-01-04  1132.989990  30.642857  31.100000  1133.869995  30.340000
# 2010-01-05  1136.520020  30.798571  31.100000  1136.630005  30.464285
# 2010-01-06  1137.140015  30.747143  31.080000  1139.189941  30.107143
# 2010-01-07  1141.689941  30.285715  30.700001  1142.459961  29.864286
# 2010-01-08  1144.979980  30.285715  30.879999  1145.390015  29.865715
# 2010-01-11  1146.979980  30.428572  30.760000  1149.739990  29.778572
# 2010-01-12  1136.219971  29.967142  30.400000  1143.810059  29.488571
# 2010-01-13  1145.680054  30.132856  30.520000  1148.400024  29.157143
#
# Attributes                               Open                          \
# Symbols          MSFT        ^GSPC       AAPL       MSFT        ^GSPC
# Date
# 2009-12-31  30.480000  1114.810059  30.447144  30.980000  1126.599976
# 2010-01-04  30.590000  1116.560059  30.490000  30.620001  1116.560059
# 2010-01-05  30.639999  1129.660034  30.657143  30.850000  1132.660034
# 2010-01-06  30.520000  1133.949951  30.625713  30.879999  1135.709961
# 2010-01-07  30.190001  1131.319946  30.250000  30.629999  1136.270020
# 2010-01-08  30.240000  1136.219971  30.042856  30.280001  1140.520020
# 2010-01-11  30.120001  1142.020020  30.400000  30.709999  1145.959961
# 2010-01-12  29.910000  1131.770020  29.884285  30.150000  1143.810059
# 2010-01-13  30.010000  1133.180054  29.695715  30.260000  1137.310059
#
# Attributes       Volume
# Symbols            AAPL        MSFT         ^GSPC
# Date
# 2009-12-31   88102700.0  31929700.0  2.076990e+09
# 2010-01-04  123432400.0  38409100.0  3.991400e+09
# 2010-01-05  150476200.0  49749600.0  2.491020e+09
# 2010-01-06  138040000.0  58182400.0  4.972660e+09
# 2010-01-07  119282800.0  50559700.0  5.270680e+09
# 2010-01-08  111902700.0  51197400.0  4.389590e+09
# 2010-01-11  115557400.0  68754700.0  4.255780e+09
# 2010-01-12  148614900.0  65912100.0  4.716160e+09
# 2010-01-13  151473000.0  51863500.0  4.170360e+09

# %%
close = panel_data['Close']
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')
lose = close.reindex(all_weekdays)
close = close.fillna(method='ffill')
print(all_weekdays)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-04', '2010-01-05', '2010-01-06',
#                '2010-01-07', '2010-01-08', '2010-01-11', '2010-01-12',
#                '2010-01-13', '2010-01-14',
#                ...
#                '2016-12-19', '2016-12-20', '2016-12-21', '2016-12-22',
#                '2016-12-23', '2016-12-26', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', length=1826, freq='B')

# %%
close.head(10)
# Out:
# Symbols          AAPL       MSFT        ^GSPC
# Date
# 2009-12-31  30.104286  30.480000  1115.099976
# 2010-01-04  30.572857  30.950001  1132.989990
# 2010-01-05  30.625713  30.959999  1136.520020
# 2010-01-06  30.138571  30.770000  1137.140015
# 2010-01-07  30.082857  30.450001  1141.689941
# 2010-01-08  30.282858  30.660000  1144.979980
# 2010-01-11  30.015715  30.270000  1146.979980
# 2010-01-12  29.674286  30.070000  1136.219971
# 2010-01-13  30.092857  30.350000  1145.680054
# 2010-01-14  29.918571  30.959999  1148.459961

# %%
close.describe()
# Out:
# Symbols         AAPL         MSFT        ^GSPC
# count    1763.000000  1763.000000  1763.000000
# mean       79.374720    37.126069  1645.408530
# std        28.347079    10.808787   371.402844
# min        27.435715    23.010000  1022.580017
# 25%        55.372858    27.840000  1310.159973
# 50%        78.432854    33.020000  1650.469971
# 75%       103.065002    46.105000  2020.714966
# max       133.000000    63.619999  2271.719971

# %%
msft = close.loc[:, 'MSFT']


short_rolling_msft = msft.rolling(window=20).mean()
long_rolling_msft = msft.rolling(window=100).mean()

fig, ax = plt.subplots(figsize=(16,9))

ax.plot(msft.index, msft, label='MSFT')
ax.plot(short_rolling_msft.index, short_rolling_msft, label='20 days rolling')
ax.plot(long_rolling_msft.index, long_rolling_msft, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()
